# %%
import pandas as pd

# Đường dẫn tới file CSV
file_path = "/content/drive/MyDrive/DATN/Banking.csv"

# Đọc file CSV
df = pd.read_csv(file_path)

# Hiển thị 5 dòng đầu
df.head()
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df.shape
# Out:
# (3000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
# Kiểm tra số lượng giá trị Null của từng cột
df.isnull().sum()
# Out:
# Client ID                   0
# Name                        0
# Age                         0
# Location ID                 0
# Joined Bank                 0
# Banking Contact             0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Credit Card Balance         0
# Bank Loans                  0
# Bank Deposits               0
# Checking Accounts           0
# Saving Accounts             0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# IAId                        0
# dtype: int64

# %%
# Chỉ hiển thị các cột có giá trị Null
null_values = df.isnull().sum()
null_values[null_values > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # Chia khách hàng thành 3 nhóm thu nhập:
#
# Low: thu nhập thấp
# Med: thu nhập trung bình
# High: thu nhập cao

# %%
bins = [0, 100000, 300000, float('inf')]
labels = ['Low', 'Med', 'High' ]
df['Income Band' ] = pd. cut(df['Estimated Income'], bins=bins, labels=labels, right=False)
df['Income Band' ] . value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Income Band'>

# %% [markdown]
# # Đếm số lượng khách hàng trong từng nhóm.
# Để hiểu dữ liệu đang phân bố như thế nào.

# %%
# Examine the distribution of unique cataegories in categorical columns
categorical_cols = df[["BRId", "GenderId", "IAId", "Amount of Credit Cards",
                       "Nationality", "Occupation", "Fee Structure", "Loyalty Classification",
                       "Properties Owned", "Risk Weighting", "Income Band"]].columns
for col in categorical_cols:
    print(f"Value Counts for '{col}':")
    display(df[col].value_counts())
# Out:
# Value Counts for 'BRId':
# BRId
# 3    1352
# 1     660
# 2     495
# 4     493
# Name: count, dtype: int64
# Value Counts for 'GenderId':
# GenderId
# 2    1512
# 1    1488
# Name: count, dtype: int64
# Value Counts for 'IAId':
# IAId
# 1     177
# 2     177
# 3     177
# 4     177
# 8     177
# 9     176
# 13    176
# 12    176
# 10    176
# 11    176
# 14    176
# 15    176
# 6      89
# 5      89
# 7      89
# 16     88
# 17     88
# 18     88
# 19     88
# 20     88
# 21     88
# 22     88
# Name: count, dtype: int64
# Value Counts for 'Amount of Credit Cards':
# Amount of Credit Cards
# 1    1922
# 2     765
# 3     313
# Name: count, dtype: int64
# Value Counts for 'Nationality':
# Nationality
# European      1309
# Asian          754
# American       507
# Australian     254
# African        176
# Name: count, dtype: int64
# Value Counts for 'Occupation':
# Occupation
# Associate Professor             28
# Structural Analysis Engineer    28
# ...

# %% [markdown]
# # Phân tích đơn biến
# Phân tích từng biến một.
#
# Ví dụ xem:
#
# Có bao nhiêu khách hàng thuộc từng nghề nghiệp?
# Có bao nhiêu khách hàng thuộc từng nhóm thu nhập?
# Có bao nhiêu khách hàng ở từng quốc tịch?
#
# 👉 Tại sao: Trước khi tìm mối quan hệ giữa các dữ liệu, mình cần hiểu từng dữ liệu riêng lẻ trước.
#
# Ví dụ:
#
# Trước khi hỏi nghề nghiệp có ảnh hưởng tới khoản vay không, mình phải biết dữ liệu hiện có những nghề nghiệp nào và số lượng từng nghề.

# %%
for i, predictor in enumerate(df[["BRId", "GenderId", "IAId", "Amount of Credit Cards",
                       "Nationality", "Occupation", "Fee Structure", "Loyalty Classification",
                       "Properties Owned", "Risk Weighting", "Income Band"]]):
    plt.figure(i)
    # Vẽ biểu đồ đếm số lượng khách hàng trong từng nhóm và chia theo giới tính
    sns. countplot(data=df, x=predictor, hue='GenderId')

# %% [markdown]
# # Phân tích hai biến số
# So sánh hai đặc điểm với nhau.
# Để tìm xem hai yếu tố có sự khác biệt hoặc liên quan gì không.
#
# Ví dụ:
#
# Nghề nghiệp của khách hàng có phân bố khác nhau giữa các quốc tịch không?
#
# Khác với đơn biến:
#
# Đơn biến: xem nghề nghiệp.
# Hai biến: xem nghề nghiệp theo quốc tịch.

# %%
for i, predictor in enumerate(df[["BRId", "GenderId", "IAId", "Amount of Credit Cards",
                                  "Nationality", "Occupation", "Fee Structure", "Loyalty Classification",
                                  "Properties Owned", "Risk Weighting", "Income Band"]]):
    plt.figure(i)
    sns. countplot(data=df, x=predictor, hue='Nationality')

# %% [markdown]
# # Biểu đồ histogram của số lượng (value counts) cho các nghề nghiệp khác nhau
# Vẽ phân bố số lượng khách hàng theo nghề nghiệp
# Để nhìn nhanh nghề nào xuất hiện nhiều, nghề nào ít.

# %%
for col in categorical_cols:
    if col == "Occupation":
        continue
    plt.figure(figsize=(8,4))
    sns.histplot (df [col])
    plt.title('Histogram of Occupation Count')
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %% [markdown]
# # Numerical Analysis
# Phân tích riêng các cột dữ liệu dạng số.
# Dữ liệu dạng số cần cách phân tích khác dữ liệu phân loại.
#
# Mục đích là xem:
#
# Giá trị tập trung ở đâu?
#
# Dữ liệu phân bố thế nào?
#
# Có giá trị bất thường không?

# %%
numerical_cols = [
    'Estimated Income', 'Superannuation Savings',
    'Credit Card Balance', 'Bank Loans',
    'Bank Deposits', 'Checking Accounts',
    'Saving Accounts', 'Foreign Currency Account',
    'Business Lending'
]

plt.figure(figsize=(18, 12))

for i, col in enumerate(numerical_cols):
    plt.subplot(3, 3, i + 1)
    sns.histplot(df[col], kde=True)
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Biểu đồ nhiệt
# Kiểm tra mức độ tương quan giữa các biến số.
#
# Để tìm xem hai biến có xu hướng liên quan với nhau không.

# %%
numerical_cols = [
    'Estimated Income',
    'Superannuation Savings',
    'Credit Card Balance',
    'Bank Loans',
    'Bank Deposits',
    'Checking Accounts',
    'Saving Accounts',
    'Foreign Currency Account',
    'Business Lending'
]

correlation_matrix = df[numerical_cols].corr()

plt.figure(figsize=(12, 12))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap="crest",
    fmt=".2f"
)

plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# # Nhận xét
#
# 1. Mối tương quan dương mạnh nhất xảy ra giữa "Tiền gửi ngân hàng" với "Tài khoản séc", "Tài khoản tiết kiệm" và "Tài khoản ngoại tệ", cho thấy những khách hàng duy trì số dư cao ở một loại tài khoản thường cũng có khoản tiền đáng kể trong các tài khoản khác.
